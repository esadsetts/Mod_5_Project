# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

import xgboost as xgb

# %%
df = pd.read_csv('database.csv', index_col = 0)
df
# Out:
#                 club_name      player_name  age          position  \
# 0     Feyenoord Rotterdam  Steven Berghuis   25      Right Winger
# 1     Feyenoord Rotterdam  Ridgeciano Haps   24         Left-Back
# 2     Feyenoord Rotterdam   Sofyan Amrabat   20  Central Midfield
# 3          ACF Fiorentina   Sofyan Amrabat   23  Central Midfield
# 4           Hellas Verona   Sofyan Amrabat   23  Central Midfield
# ...                   ...              ...  ...               ...
# 1604           CA Osasuna     Marc Cardona   23    Centre-Forward
# 1605           CA Osasuna    Robert Ibáñez   26      Right Winger
# 1606           Granada CF    Darwin Machís   26       Left Winger
# 1607           Granada CF  Domingos Duarte   24       Centre-Back
# 1608         RCD Mallorca   Yannis Salibur   28      Right Winger
#
#      club_involved_name     fee transfer_movement  fee_cleaned  \
# 0               Watford  £5.85m                in         5.85
# 1            AZ Alkmaar  £5.40m                in         5.40
# 2            FC Utrecht  £3.60m                in         3.60
# 3         Hellas Verona  £9.49m                in         9.49
# 4           Club Brugge  £3.15m                in         3.15
# ...                 ...     ...               ...          ...
# 1604       FC Barcelona  £2.25m                in         2.25
# 1605             Getafe  £1.80m                in         1.80
# 1606     Udinese Calcio  £2.70m                in         2.70
# 1607        Sporting CP  £2.70m                in         2.70
# 1608           Guingamp  £1.80m                in         1.80
#
#            league_name  year  ... Goals-PKs/90 Goals+Assists-PKs/90   xG  \
# 0           Eredivisie  2017  ...         0.30                 0.51  NaN
# 1           Eredivisie  2017  ...         0.00                 0.07  NaN
# 2           Eredivisie  2017  ...         0.00                 0.18  NaN
# 3              Serie A  2019  ...         0.08                 0.08  NaN
# 4              Serie A  2019  ...         0.08                 0.08  NaN
# ...                ...   ...  ...          ...                  ...  ...
# 1604  Primera Division  2019  ...         0.45                 0.60  2.7
# 1605  Primera Division  2019  ...         0.00                 0.00  0.2
# 1606  Primera Division  2019  ...         0.00                 0.19  1.3
# 1607  Primera Division  2019  ...         0.10                 0.10  NaN
# 1608  Primera Division  2019  ...         0.00                 0.00  0.0
#
#       npxG   xA xG/90  xA/90  xG+xA/90  npxG/90  npxG+xA/90
# 0      NaN  NaN   NaN    NaN       NaN      NaN         NaN
# 1      NaN  NaN   NaN    NaN       NaN      NaN         NaN
# 2      NaN  NaN   NaN    NaN       NaN      NaN         NaN
# 3      NaN  NaN   NaN    NaN       NaN      NaN         NaN
# 4      NaN  NaN   NaN    NaN       NaN      NaN         NaN
# ...    ...  ...   ...    ...       ...      ...         ...
# 1604   2.7  0.6  0.41   0.10      0.50     0.41        0.50
# 1605   0.2  0.0  0.25   0.00      0.25     0.25        0.25
# 1606   1.3  0.6  0.26   0.12      0.38     0.26        0.38
# 1607   NaN  NaN   NaN    NaN       NaN      NaN         NaN
# 1608   0.0  0.0  0.00   0.23      0.23     0.00        0.23
#
# [1609 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1609 entries, 0 to 1608
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   club_name             1609 non-null   object
#  1   player_name           1609 non-null   object
#  2   age                   1609 non-null   int64
#  3   position              1609 non-null   object
#  4   club_involved_name    1609 non-null   object
#  5   fee                   1609 non-null   object
#  6   transfer_movement     1609 non-null   object
#  7   fee_cleaned           1609 non-null   float64
#  8   league_name           1609 non-null   object
#  9   year                  1609 non-null   int64
#  10  season                1609 non-null   object
#  11  links                 1609 non-null   object
#  12  Season                1533 non-null   object
#  13  Matches               1533 non-null   float64
#  14  Starts                1533 non-null   float64
#  15  Minutes               1494 non-null   object
#  16  Goals                 1494 non-null   float64
#  17  Assists               1489 non-null   float64
#  18  Penalty_Goals         1489 non-null   float64
#  19  Penalty_Attempts      1489 non-null   float64
#  20  Yellow_Cards          1489 non-null   float64
#  21  Red_Cards             1494 non-null   float64
#  22  Goals/90              1494 non-null   float64
#  23  Assists/90            1489 non-null   float64
#  24  Goals+Assists/90      1489 non-null   float64
#  25  Goals-PKs/90          1494 non-null   float64
#  26  Goals+Assists-PKs/90  1488 non-null   float64
#  27  xG                    509 non-null    float64
#  28  npxG                  509 non-null    float64
#  29  xA                    509 non-null    float64
#  30  xG/90                 432 non-null    float64
#  31  xA/90                 432 non-null    float64
#  32  xG+xA/90              432 non-null    float64
#  33  npxG/90               432 non-null    float64
#  34  npxG+xA/90            432 non-null    float64
# dtypes: float64(22), int64(2), object(11)
# memory usage: 452.5+ KB

# %%
df.xG.fillna(df.Goals, inplace = True)
df.npxG.fillna(df.Goals - df.Penalty_Goals, inplace = True)
df.xA.fillna(df.Assists, inplace = True)
df['xG/90'].fillna(df['Goals/90'], inplace = True)
df['xA/90'].fillna(df['Assists/90'], inplace = True)
df['xG+xA/90'].fillna(df['Goals+Assists/90'], inplace = True)
df['npxG/90'].fillna(df['Goals-PKs/90'], inplace = True)
df['npxG+xA/90'].fillna(df['Goals+Assists-PKs/90'], inplace = True)

# %%
df.dropna(subset = ['Season'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1533 entries, 0 to 1608
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   club_name             1533 non-null   object
#  1   player_name           1533 non-null   object
#  2   age                   1533 non-null   int64
#  3   position              1533 non-null   object
#  4   club_involved_name    1533 non-null   object
#  5   fee                   1533 non-null   object
#  6   transfer_movement     1533 non-null   object
#  7   fee_cleaned           1533 non-null   float64
#  8   league_name           1533 non-null   object
#  9   year                  1533 non-null   int64
#  10  season                1533 non-null   object
#  11  links                 1533 non-null   object
#  12  Season                1533 non-null   object
#  13  Matches               1533 non-null   float64
#  14  Starts                1533 non-null   float64
#  15  Minutes               1494 non-null   object
#  16  Goals                 1494 non-null   float64
#  17  Assists               1489 non-null   float64
#  18  Penalty_Goals         1489 non-null   float64
#  19  Penalty_Attempts      1489 non-null   float64
#  20  Yellow_Cards          1489 non-null   float64
#  21  Red_Cards             1494 non-null   float64
#  22  Goals/90              1494 non-null   float64
#  23  Assists/90            1489 non-null   float64
#  24  Goals+Assists/90      1489 non-null   float64
#  25  Goals-PKs/90          1494 non-null   float64
#  26  Goals+Assists-PKs/90  1488 non-null   float64
#  27  xG                    1494 non-null   float64
#  28  npxG                  1494 non-null   float64
#  29  xA                    1489 non-null   float64
#  30  xG/90                 1494 non-null   float64
#  31  xA/90                 1489 non-null   float64
#  32  xG+xA/90              1489 non-null   float64
#  33  npxG/90               1494 non-null   float64
#  34  npxG+xA/90            1488 non-null   float64
# dtypes: float64(22), int64(2), object(11)
# memory usage: 431.2+ KB

# %%
df.fillna(0, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1533 entries, 0 to 1608
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   club_name             1533 non-null   object
#  1   player_name           1533 non-null   object
#  2   age                   1533 non-null   int64
#  3   position              1533 non-null   object
#  4   club_involved_name    1533 non-null   object
#  5   fee                   1533 non-null   object
#  6   transfer_movement     1533 non-null   object
#  7   fee_cleaned           1533 non-null   float64
#  8   league_name           1533 non-null   object
#  9   year                  1533 non-null   int64
#  10  season                1533 non-null   object
#  11  links                 1533 non-null   object
#  12  Season                1533 non-null   object
#  13  Matches               1533 non-null   float64
#  14  Starts                1533 non-null   float64
#  15  Minutes               1533 non-null   object
#  16  Goals                 1533 non-null   float64
#  17  Assists               1533 non-null   float64
#  18  Penalty_Goals         1533 non-null   float64
#  19  Penalty_Attempts      1533 non-null   float64
#  20  Yellow_Cards          1533 non-null   float64
#  21  Red_Cards             1533 non-null   float64
#  22  Goals/90              1533 non-null   float64
#  23  Assists/90            1533 non-null   float64
#  24  Goals+Assists/90      1533 non-null   float64
#  25  Goals-PKs/90          1533 non-null   float64
#  26  Goals+Assists-PKs/90  1533 non-null   float64
#  27  xG                    1533 non-null   float64
#  28  npxG                  1533 non-null   float64
#  29  xA                    1533 non-null   float64
#  30  xG/90                 1533 non-null   float64
#  31  xA/90                 1533 non-null   float64
#  32  xG+xA/90              1533 non-null   float64
#  33  npxG/90               1533 non-null   float64
#  34  npxG+xA/90            1533 non-null   float64
# dtypes: float64(22), int64(2), object(11)
# memory usage: 431.2+ KB

# %%
df.Minutes = df.Minutes.apply(lambda x: str(x).replace(',', ''))

# %%
df.Minutes = df.Minutes.astype('int64')

# %%
df.position.value_counts()
# Out:
# Centre-Back           281
# Centre-Forward        265
# Central Midfield      207
# Left Winger           123
# Right Winger          117
# Right-Back            116
# Left-Back             114
# Defensive Midfield    111
# Goalkeeper             79
# Attacking Midfield     73
# Left Midfield          20
# Second Striker         16
# Right Midfield         11
# Name: position, dtype: int64

# %%
defence_dic = {'Centre-Back': 1, 'Centre-Forward': 0, 'Central Midfield': 0, 'Left Winger': 0, 'Right Winger': 0,
               'Right-Back': 1, 'Left-Back': 1, 'Defensive Midfield': 0, 'Goalkeeper': 1, 'Attacking Midfield': 0,
               'Left Midfield': 0, 'Second Striker': 0, 'Right Midfield': 0}
midfield_dic = {'Centre-Back': 0, 'Centre-Forward': 0, 'Central Midfield': 1, 'Left Winger': 0, 'Right Winger': 0,
                'Right-Back': 0, 'Left-Back': 0, 'Defensive Midfield': 1, 'Goalkeeper': 0, 'Attacking Midfield': 1,
                'Left Midfield': 1, 'Second Striker': 0, 'Right Midfield': 1}
attack_dic = {'Centre-Back': 0, 'Centre-Forward': 1, 'Central Midfield': 0, 'Left Winger': 1, 'Right Winger': 1,
              'Right-Back': 0, 'Left-Back': 0, 'Defensive Midfield': 0, 'Goalkeeper': 1, 'Attacking Midfield': 0,
              'Left Midfield': 0, 'Second Striker': 0, 'Right Midfield': 0}

# %%
df['is_defence'] = df.position.replace(defence_dic)
df['is_midfield'] = df.position.replace(midfield_dic)
df['is_attack'] = df.position.replace(attack_dic)

# %%
df.groupby('year').fee_cleaned.mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.groupby('league_name').fee_cleaned.mean().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='league_name'>

# %%
df.groupby('age').fee_cleaned.mean().plot()
# Out:
# <AxesSubplot:xlabel='age'>

# %%
df.groupby('position').fee_cleaned.mean().sort_values().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='position'>

# %%
sns.distplot(df.fee_cleaned)
# Out:
# <AxesSubplot:xlabel='fee_cleaned'>

# %%
df.fee_cleaned.describe()
# Out:
# count    1533.000000
# mean        8.058299
# std        12.295695
# min         0.045000
# 25%         1.800000
# 50%         3.600000
# 75%         9.630000
# max       130.500000
# Name: fee_cleaned, dtype: float64

# %%
df_features = df[['age','position','Starts','Minutes','Goals','Assists','Penalty_Goals','Penalty_Attempts',
                  'Yellow_Cards','Red_Cards','Goals/90','Assists/90','Goals+Assists/90','Goals-PKs/90',
                  'Goals+Assists-PKs/90','xG','npxG','xA','xG/90','xA/90','xG+xA/90','npxG/90','npxG+xA/90',
                  'is_defence', 'is_midfield', 'is_attack']]

# %%
df_categoricals = df_features[['position', 'is_defence', 'is_midfield', 'is_attack']]
df_features.columns
# Out:
# Index(['age', 'position', 'Starts', 'Minutes', 'Goals', 'Assists',
#        'Penalty_Goals', 'Penalty_Attempts', 'Yellow_Cards', 'Red_Cards',
#        'Goals/90', 'Assists/90', 'Goals+Assists/90', 'Goals-PKs/90',
#        'Goals+Assists-PKs/90', 'xG', 'npxG', 'xA', 'xG/90', 'xA/90',
#        'xG+xA/90', 'npxG/90', 'npxG+xA/90', 'is_defence', 'is_midfield',
#        'is_attack'],
#       dtype='object')

# %%
for column in df_features.columns:
    if column not in df_categoricals.columns:
        sns.distplot(df_features[column], kde = False)
        figure  = plt.figure()
# Out:
# /Users/ericadsetts/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.

# %%
for column in df_features.columns:
    if column not in df_categoricals.columns:
        plt.scatter(df_features[column], df_target)
        plt.xlabel(column)
        plt.show()

# %%
df_dummies = pd.get_dummies(df_features.position)
df_features = pd.concat([df_features, df_dummies], axis = 1)
df_features.drop(['position'], axis = 1, inplace = True)

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1533 entries, 0 to 1608
# Data columns (total 38 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   1533 non-null   int64
#  1   Starts                1533 non-null   float64
#  2   Minutes               1533 non-null   int64
#  3   Goals                 1533 non-null   float64
#  4   Assists               1533 non-null   float64
#  5   Penalty_Goals         1533 non-null   float64
#  6   Penalty_Attempts      1533 non-null   float64
#  7   Yellow_Cards          1533 non-null   float64
#  8   Red_Cards             1533 non-null   float64
#  9   Goals/90              1533 non-null   float64
#  10  Assists/90            1533 non-null   float64
#  11  Goals+Assists/90      1533 non-null   float64
#  12  Goals-PKs/90          1533 non-null   float64
#  13  Goals+Assists-PKs/90  1533 non-null   float64
#  14  xG                    1533 non-null   float64
#  15  npxG                  1533 non-null   float64
#  16  xA                    1533 non-null   float64
#  17  xG/90                 1533 non-null   float64
#  18  xA/90                 1533 non-null   float64
#  19  xG+xA/90              1533 non-null   float64
#  20  npxG/90               1533 non-null   float64
#  21  npxG+xA/90            1533 non-null   float64
#  22  is_defence            1533 non-null   int64
#  23  is_midfield           1533 non-null   int64
#  24  is_attack             1533 non-null   int64
#  25  Attacking Midfield    1533 non-null   uint8
#  26  Central Midfield      1533 non-null   uint8
#  27  Centre-Back           1533 non-null   uint8
#  28  Centre-Forward        1533 non-null   uint8
#  29  Defensive Midfield    1533 non-null   uint8
#  30  Goalkeeper            1533 non-null   uint8
#  31  Left Midfield         1533 non-null   uint8
#  32  Left Winger           1533 non-null   uint8
#  33  Left-Back             1533 non-null   uint8
#  34  Right Midfield        1533 non-null   uint8
#  35  Right Winger          1533 non-null   uint8
#  36  Right-Back            1533 non-null   uint8
#  37  Second Striker        1533 non-null   uint8
# dtypes: float64(20), int64(5), uint8(13)
# memory usage: 330.9 KB

# %%
df_target = df.fee_cleaned

# %%
X_train, X_test, y_train, y_test = train_test_split(df_features, df_target)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
dummy = DummyRegressor()
dummy.fit(X_train, y_train)
y_train_preds = dummy.predict(X_train)
mean_squared_error(y_train, y_train_preds)
# Out:
# 165.75244768780664

# %%
y_preds = dummy.predict(X_test)
mean_squared_error(y_test, y_preds)
# Out:
# 107.42847471110683

# %%
line = LinearRegression(n_jobs = -1)
line.fit(X_train, y_train)
y_train_preds = line.predict(X_train)
mean_squared_error(y_train, y_train_preds)
# Out:
# 145.9973197568715

# %%
y_preds = line.predict(X_test)
mean_squared_error(y_test, y_preds)
# Out:
# 111.20388554411757

# %%
sorted(list(zip(line.coef_, df_features.columns)))
# Out:
# [(-1658.7827525521436, 'npxG/90'),
#  (-436.88725424282666, 'xA/90'),
#  (-349.4875657082395, 'Goals+Assists-PKs/90'),
#  (-246.30391224988054, 'xG+xA/90'),
#  (-155.17050307991684, 'Goals/90'),
#  (-6.025695979107997, 'Penalty_Goals'),
#  (-4.830266295251016, 'Starts'),
#  (-3.7461867273577893, 'xA'),
#  (-1.4302688211224153, 'Goalkeeper'),
#  (-1.1204407353882337, 'Yellow_Cards'),
#  (-0.6426512352607594, 'Left Midfield'),
#  (-0.6198157682161662, 'is_attack'),
#  (-0.5192037001705107, 'Attacking Midfield'),
#  (-0.4385554186117209, 'age'),
#  (-0.3613070591093366, 'Centre-Forward'),
#  (-0.32568871636370206, 'Right Midfield'),
#  (-0.2660276600758485, 'Left-Back'),
#  (-0.24143234370706138, 'is_midfield'),
#  (-0.1478587066558674, 'is_defence'),
#  (-0.09737692684423332, 'Right Winger'),
#  (-0.08837472910122808, 'Central Midfield'),
#  (-0.08726701770352398, 'Right-Back'),
#  (-0.08336924042471364, 'Red_Cards'),
#  (0.5174799167599783, 'Defensive Midfield'),
#  (0.6359930820598646, 'xG'),
#  (0.675835704370585, 'Left Winger'),
#  (0.7017750670932483, 'npxG'),
#  (0.8963465372694879, 'Centre-Back'),
#  (1.5882864481849244, 'Second Striker'),
#  (2.7530925188620237, 'Goals'),
#  (4.544579791225405, 'Penalty_Attempts'),
#  (4.965671252078659, 'Minutes'),
#  (5.608923670644557, 'Assists'),
#  (153.95068600884358, 'xG/90'),
#  (247.52936430807546, 'Goals+Assists/90'),
#  (345.87932344930726, 'npxG+xA/90'),
#  (436.4252626760732, 'Assists/90'),
#  (1660.2756419077389, 'Goals-PKs/90')]

# %%
ridge = Ridge()
ridge.fit(X_train, y_train)
y_train_preds = ridge.predict(X_train)
mean_squared_error(y_train, y_train_preds)
# Out:
# 146.6101439612487

# %%
y_preds = ridge.predict(X_test)
mean_squared_error(y_test, y_preds)
# Out:
# 112.18509006937306

# %%
sorted(list(zip(ridge.coef_, df_features.columns)))
# Out:
# [(-4.170154175401486, 'xG/90'),
#  (-4.041829595479946, 'Penalty_Goals'),
#  (-3.87735995084602, 'Starts'),
#  (-2.9810999319080036, 'xA'),
#  (-2.790676114764588, 'Goals+Assists-PKs/90'),
#  (-2.76220627141982, 'Assists/90'),
#  (-1.372545369945436, 'Goalkeeper'),
#  (-1.1435774269128247, 'Yellow_Cards'),
#  (-0.6572717456245997, 'Left Midfield'),
#  (-0.6105491843301181, 'is_attack'),
#  (-0.5261423334072332, 'Attacking Midfield'),
#  (-0.42057009355233554, 'age'),
#  (-0.414489891359221, 'Centre-Forward'),
#  (-0.3071144936030701, 'Right Midfield'),
#  (-0.2562680484612153, 'Left-Back'),
#  (-0.23980384113663442, 'is_midfield'),
#  (-0.1529896881880642, 'npxG/90'),
#  (-0.1464847620500689, 'Red_Cards'),
#  (-0.13513314729487808, 'is_defence'),
#  (-0.09380899432710885, 'Central Midfield'),
#  (-0.08974674365580244, 'Right-Back'),
#  (-0.07187381543749846, 'Right Winger'),
#  (0.27264284671795047, 'Goals+Assists/90'),
#  (0.2919042491853993, 'xG+xA/90'),
#  (0.5333672462860741, 'Defensive Midfield'),
#  (0.6906047203319202, 'Left Winger'),
#  (0.7183348646420714, 'npxG'),
#  (0.7217847059682838, 'xG'),
#  (0.8734702100792426, 'Centre-Back'),
#  (1.2408083660287283, 'Goals-PKs/90'),
#  (1.6058678424944186, 'Second Striker'),
#  (2.1300272932565467, 'xA/90'),
#  (2.2105078730529035, 'npxG+xA/90'),
#  (2.6072194978666343, 'Goals'),
#  (2.769913469399289, 'Penalty_Attempts'),
#  (3.4665554049149714, 'Goals/90'),
#  (4.034421477408935, 'Minutes'),
#  (4.824579424128387, 'Assists')]

# %%
lasso = Lasso()
lasso.fit(X_train, y_train)
y_train_preds = lasso.predict(X_train)
mean_squared_error(y_train, y_train_preds)
# Out:
# 154.26985487709572

# %%
y_preds = lasso.predict(X_test)
mean_squared_error(y_test, y_preds)
# Out:
# 104.83571598851893

# %%
sorted(list(zip(lasso.coef_, df_features.columns)))
# Out:
# [(-0.0, 'Assists/90'),
#  (-0.0, 'Attacking Midfield'),
#  (-0.0, 'Central Midfield'),
#  (0.0, 'Centre-Back'),
#  (-0.0, 'Centre-Forward'),
#  (0.0, 'Defensive Midfield'),
#  (-0.0, 'Goalkeeper'),
#  (0.0, 'Goals'),
#  (-0.0, 'Goals+Assists-PKs/90'),
#  (-0.0, 'Goals+Assists/90'),
#  (-0.0, 'Goals-PKs/90'),
#  (-0.0, 'Goals/90'),
#  (-0.0, 'Left Midfield'),
#  (0.0, 'Left Winger'),
#  (-0.0, 'Left-Back'),
#  (0.0, 'Minutes'),
#  (-0.0, 'Penalty_Attempts'),
#  (-0.0, 'Penalty_Goals'),
#  (-0.0, 'Red_Cards'),
#  (-0.0, 'Right Midfield'),
#  (0.0, 'Right Winger'),
#  (-0.0, 'Right-Back'),
#  (0.0, 'Starts'),
#  (-0.0, 'Yellow_Cards'),
#  (-0.0, 'age'),
#  (0.0, 'is_attack'),
#  (-0.0, 'is_defence'),
#  (-0.0, 'is_midfield'),
#  (-0.0, 'npxG+xA/90'),
#  (-0.0, 'npxG/90'),
#  (0.0, 'xA'),
#  (-0.0, 'xA/90'),
#  (-0.0, 'xG+xA/90'),
#  (-0.0, 'xG/90'),
#  (0.5616247405482642, 'npxG'),
#  (0.7708716025971128, 'xG'),
#  (0.8131191331938157, 'Second Striker'),
#  (1.057340982855022, 'Assists')]

# %%
svr = SVR()
svr.fit(X_train, y_train)
y_train_preds = svr.predict(X_train)
mean_squared_error(y_train, y_train_preds)
# Out:
# 174.18072942516028

# %%
y_preds = svr.predict(X_test)
mean_squared_error(y_test, y_preds)
# Out:
# 113.37324939432266

# %%
tree = DecisionTreeRegressor()
tree.fit(X_train, y_train)
y_train_preds = tree.predict(X_train)
mean_squared_error(y_train, y_train_preds)
# Out:
# 0.10291135770234987

# %%
y_preds = tree.predict(X_test)
mean_squared_error(y_test, y_preds)
# Out:
# 237.895271296875

# %%
rf = RandomForestRegressor(n_jobs = -1)
rf.fit(X_train, y_train)
y_train_preds = rf.predict(X_train)
mean_squared_error(y_train, y_train_preds)
# Out:
# 21.7367828377739

# %%
y_preds = rf.predict(X_test)
mean_squared_error(y_test, y_preds)
# Out:
# 124.9856692151443

# %%
xg = xgb.XGBRegressor(n_jobs = -1)
xg.fit(X_train, y_train)
y_train_preds = xg.predict(X_train)
mean_squared_error(y_train, y_train_preds)
# Out:
# 1.4067107657779665

# %%
y_preds = xg.predict(X_test)
mean_squared_error(y_test, y_preds)
# Out:
# 139.4963803729597

# %%
sorted(zip(xg.feature_importances_, df_features.columns))
# Out:
# [(0.0, 'Goalkeeper'),
#  (0.0024056472, 'Centre-Forward'),
#  (0.0026157694, 'Right Midfield'),
#  (0.002642305, 'Left-Back'),
#  (0.0047408044, 'Right Winger'),
#  (0.0048984117, 'Right-Back'),
#  (0.0054037184, 'Defensive Midfield'),
#  (0.006057914, 'Left Midfield'),
#  (0.006958277, 'Penalty_Goals'),
#  (0.007286943, 'Attacking Midfield'),
#  (0.0073035257, 'Red_Cards'),
#  (0.008110046, 'age'),
#  (0.008591794, 'is_attack'),
#  (0.008724159, 'Central Midfield'),
#  (0.009286261, 'is_defence'),
#  (0.012105628, 'xA/90'),
#  (0.012490167, 'Assists/90'),
#  (0.013255873, 'Goals'),
#  (0.015355218, 'Minutes'),
#  (0.016171169, 'Starts'),
#  (0.017760117, 'npxG+xA/90'),
#  (0.019425556, 'Goals-PKs/90'),
#  (0.019683298, 'Penalty_Attempts'),
#  (0.019874651, 'Assists'),
#  (0.023348968, 'Goals/90'),
#  (0.02342897, 'xG/90'),
#  (0.026603257, 'Goals+Assists/90'),
#  (0.027636334, 'xA'),
#  (0.02959421, 'Yellow_Cards'),
#  (0.031474434, 'xG+xA/90'),
#  (0.03370058, 'is_midfield'),
#  (0.048802383, 'xG'),
#  (0.049282786, 'npxG/90'),
#  (0.04931457, 'Centre-Back'),
#  (0.06340034, 'npxG'),
#  (0.06431201, 'Goals+Assists-PKs/90'),
#  (0.08654093, 'Left Winger'),
#  (0.21141303, 'Second Striker')]
